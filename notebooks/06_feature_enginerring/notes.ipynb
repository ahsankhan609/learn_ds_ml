# %% [markdown]
# # Data Analysis and Feature Engineering

# %% [markdown]
# [Feature Engineering - CampusX](https://www.youtube.com/watch?v=sluoVhT0ehg)

# %% [markdown]
# **Exploratory Data Analysis** (EDA) and **Feature Engineering** are two of the most important steps in the **machine learning** workflow.
#
# They help transform raw data into meaningful insights and build a strong foundation for accurate and robust models.

# %% [markdown]
# ![ml-life-cycle](course_screenshots/life-cycle.png "ml-life-cycle")

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# EDA is the process of **exploring(through Pandas)**, **understanding**, and **summarizing** datasets before applying any machine learning algorithms.
# It helps in:
#
# * Identifying data patterns and trends
# * Detecting [outliers (with box plots)](/notebooks/05_pandas/notes.ipynb) and missing values
# * Understanding variable distributions
# * Building intuition for model selection
